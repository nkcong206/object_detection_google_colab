# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
# !pip install tensorflow-gpu

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 66291, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 66291 (delta 99), reused 113 (delta 58), pack-reused 66134
# Receiving objects: 100% (66291/66291), 575.90 MiB | 31.82 MiB/s, done.
# Resolving deltas: 100% (46406/46406), done.

# %%
cd /content/models/research
# Out:
# /content/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 27.10 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
cd cocoapi/PythonAPI
# Out:
# /content/models/research/cocoapi/PythonAPI

# %%
# !make

# %%
cp -r pycocotools /content/models/research

# %%
cd ..
# Out:
# /content/models/research/cocoapi

# %%
cd ..
# Out:
# /content/models/research

# %%
cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install .

# %%
cd /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training
# Out:
# /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training

# %%
# !dpkg -i "/content/drive/MyDrive/Colab/libcudnn8_8.1.1.33-1+cuda11.2_amd64.deb"
# Out:
# (Reading database ... 155219 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.1.1.33-1+cuda11.2_amd64.deb ...
# Unpacking libcudnn8 (8.1.1.33-1+cuda11.2) over (8.0.5.39-1+cuda11.1) ...
# Setting up libcudnn8 (8.1.1.33-1+cuda11.2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/models/ssd_mobilenet_v2_fpnlite --pipeline_config_path=/content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/models/ssd_mobilenet_v2_fpnlite/pipeline.config

# %%
# !python generate_tfrecord.py -x /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/images/train -l /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/annotations/labelmap.pbtxt -o /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/annotations/train.record
# Out:
# 2021-11-05 02:09:35.943651: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Successfully created the TFRecord file: /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/annotations/train.record

# %%
# !python generate_tfrecord.py -x /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/images/test -l /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/annotations/labelmap.pbtxt -o /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/annotations/test.record
# Out:
# 2021-11-05 02:13:20.812806: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Successfully created the TFRecord file: /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/annotations/test.record

# %%
# !python export_tflite_graph_tf2.py --pipeline_config_path /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/models/ssd_mobilenet_v2_fpnlite/pipeline.config --trained_checkpoint_dir /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/models/ssd_mobilenet_v2_fpnlite --output_directory /content/drive/MyDrive/Colab/object_detetion/TensorFlow/workspace/training/models/ssd_mobilenet_v2_fpnlite
